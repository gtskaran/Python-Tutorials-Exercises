# %% [markdown]
# ### Bitwise Operators in Python
#
# | Operator | Name              | Example | Result (assuming a = 5, b = 3) |
# |----------|-------------------|---------|--------------------------------|
# | `&`      | AND               | a & b   | 1 (0101 & 0011 = 0001)         |
# | &vert; | OR                | a &#124; b | 7 (0101 &#124; 0011 = 0111)   |
# | `^`      | XOR               | a ^ b   | 6 (0101 ^ 0011 = 0110)         |
# | `~`      | NOT (bitwise neg) | ~a      | -6 (in 2’s complement)         |
# | `<<`     | Left Shift        | a << 1  | 10 (0101 << 1 = 1010)          |
# | `>>`     | Right Shift       | a >> 1  | 2 (0101 >> 1 = 0010)           |

# %% [markdown]
# <h3>Bitwise Operators in Python</h3>
#
# <table border="1">
#   <tr>
#     <th>Operator</th>
#     <th>Name</th>
#     <th>Example</th>
#     <th>Result (a = 5, b = 3)</th>
#   </tr>
#   <tr>
#     <td>&amp;</td>
#     <td>AND</td>
#     <td>a &amp; b</td>
#     <td>1 (0101 &amp; 0011 = 0001)</td>
#   </tr>
#   <tr>
#     <td>&#124;</td>
#     <td>OR</td>
#     <td>a &#124; b</td>
#     <td>7 (0101 &#124; 0011 = 0111)</td>
#   </tr>
#   <tr>
#     <td>^</td>
#     <td>XOR</td>
#     <td>a ^ b</td>
#     <td>6 (0101 ^ 0011 = 0110)</td>
#   </tr>
#   <tr>
#     <td>~</td>
#     <td>NOT</td>
#     <td>~a</td>
#     <td>-6 (2’s complement)</td>
#   </tr>
#   <tr>
#     <td>&lt;&lt;</td>
#     <td>Left Shift</td>
#     <td>a &lt;&lt; 1</td>
#     <td>10 (0101 &lt;&lt; 1 = 1010)</td>
#   </tr>
#   <tr>
#     <td>&gt;&gt;</td>
#     <td>Right Shift</td>
#     <td>a &gt;&gt; 1</td>
#     <td>2 (0101 &gt;&gt; 1 = 0010)</td>
#   </tr>
# </table>
